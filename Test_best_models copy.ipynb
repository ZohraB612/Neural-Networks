# %%
from Training import test_best_model

BEST_MLP_FP = "optuna-mlp-2021_04_19_11_28-0.008476882582539896-tanh-str" # 60.25% accuracy
BEST_CNN_FP = "optuna-cnn-2021_04_19_09_33-0.0012570317363857163-tanh-str" # 65.55% accuracy

# To test the best CNN model, use:
# config = {"activation":"tanh", "optimizer":"adam",  "network":"cnn"}
# test_best_model(config, BEST_CNN_FP)

# To test best MLP model, use:
# config = {"activation":"relu", "optimizer":"adam",  "network":"mlp"}
# test_best_model(config, BEST_MLP_FP)

if __name__ == "__main__":
    config = {"activation":"tanh", "optimizer":"adam",  "network":"cnn"}
    test_best_model(config, BEST_CNN_FP)
#     config = {"activation":"tanh", "optimizer":"adam",  "network":"mlp"}
#     test_best_model(config, BEST_MLP_FP)
# Out:
# Cats:
# Training set cat images format ['cat.2718.jpg', 'cat.3406.jpg', 'cat.1211.jpg', 'cat.1577.jpg', 'cat.952.jpg']
# Number of images in cat train 4000
# Test set cat images format ['cat.4369.jpg', 'cat.4355.jpg', 'cat.4433.jpg', 'cat.4427.jpg', 'cat.4341.jpg']
# ...
# Dogs:
# Training set dog images format ['dog.1753.jpg', 'dog.3144.jpg', 'dog.775.jpg', 'dog.3622.jpg', 'dog.1035.jpg']
# Number of images in dog train 4000
# Test set dog images format ['dog.4159.jpg', 'dog.4617.jpg', 'dog.4171.jpg', 'dog.4165.jpg', 'dog.4603.jpg']
# Original train  8000
# /Users/princessspotty/Desktop/Coursework N.C./Zohra Bouchamaoui -  Coursework Neural Computing /CNN.py:55: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = f.log_softmax(self.out(x))
# Total Predictions 2000 , correct predictions 1311
# Accuracy of the model on test set is 65.55
# [[711 289]
#  [400 600]]
# [[0.3555 0.1445]
#  [0.2    0.3   ]]
# ...
